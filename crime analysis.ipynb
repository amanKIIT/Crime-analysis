# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("india-crime.csv")

# %%
df
# Out:
#             STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1     ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2     ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3     ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4     ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
# ...              ...            ...   ...   ...                       ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012     0                         0
# 9013     LAKSHADWEEP          TOTAL  2012     0                         0
# 9014      PUDUCHERRY       KARAIKAL  2012     6                         2
# 9015      PUDUCHERRY     PUDUCHERRY  2012     7                        14
# 9016      PUDUCHERRY          TOTAL  2012    13                        16
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# ...

# %%
df.describe()
# Out:
#               Year         Rape  Kidnapping and Abduction  Dowry Deaths  \
# count  9017.000000  9017.000000               9017.000000   9017.000000
# mean   2006.629034    53.041366                 58.535433     20.228901
# std       3.463623   190.741450                246.937464     96.970466
# min    2001.000000     0.000000                  0.000000      0.000000
# 25%    2004.000000     8.000000                  6.000000      1.000000
# 50%    2007.000000    20.000000                 18.000000      5.000000
# 75%    2010.000000    41.000000                 42.000000     16.000000
# max    2012.000000  3425.000000               7910.000000   2322.000000
#
#        Assault on women with intent to outrage her modesty  \
# count                                        9017.000000
# mean                                          100.511257
# std                                           394.059436
# min                                             0.000000
# ...

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
#Q1.Draw the correlation & heatmap of all the columns

# %%
df.corr()
# Out:
#                                                         Year      Rape  \
# Year                                                1.000000  0.029702
# Rape                                                0.029702  1.000000
# Kidnapping and Abduction                            0.074188  0.728700
# Dowry Deaths                                        0.011401  0.729022
# Assault on women with intent to outrage her mod...  0.014875  0.896128
# Insult to modesty of Women                         -0.010803  0.498080
# Cruelty by Husband or his Relatives                 0.053751  0.772843
# Importation of Girls                               -0.017585  0.256228
#
#                                                     Kidnapping and Abduction  \
# Year                                                                0.074188
# Rape                                                                0.728700
# Kidnapping and Abduction                                            1.000000
# ...

# %%
dataplot = sns.heatmap(df.corr(),annot = True)
plt.show()

# %%
#Q2.Show bar plot of top 20 district with maximum rape cases

# %%
piv_rape=pd.pivot_table(df, values ='Rape', index =['DISTRICT'], aggfunc = sum)

# %%
top_rapes_by_dist = piv_rape.sort_values(by=['Rape'], ascending=False)

# %%
rape_top_20_dist = top_rapes_by_dist.head(20)
rape_top_20 = rape_top_20_dist.drop('TOTAL')
rape_top_20
# Out:
#                    Rape
# DISTRICT
# DELHI UT TOTAL     6424
# MURSHIDABAD        3352
# 24 PARGANAS SOUTH  2221
# 24 PARGANAS NORTH  1883
# JALPAIGURI         1777
# NADIA              1734
# WEST               1622
# RAIPUR             1560
# BETUL              1524
# SAGAR              1502
# NAGAON             1464
# SOUTH              1415
# DURG               1402
# MUMBAI COMMR.      1386
# DHUBRI             1363
# CHHINDWARA         1345
# MALDA              1331
# JABALPUR           1285
# BHOPAL             1272

# %%
rape_top_20.plot.bar(color = 'brown')
# Out:
# <AxesSubplot:xlabel='DISTRICT'>

# %%
#Q3.Show bar plot of top 20 State having maximum kidnapping and abduction

# %%
piv_kid = pd.pivot_table(df, values ='Kidnapping and Abduction', index =['STATE/UT'], aggfunc = sum)

# %%
top_kid_by_state = piv_kid.sort_values(by=['Kidnapping and Abduction'], ascending=False)
kid_top_20_state = top_kid_by_state.head(20)
kid_top_20_state
# Out:
#                  Kidnapping and Abduction
# STATE/UT
# UTTAR PRADESH                       95180
# RAJASTHAN                           49342
# ASSAM                               45840
# WEST BENGAL                         43546
# BIHAR                               38778
# DELHI                               31300
# ANDHRA PRADESH                      29872
# GUJARAT                             25836
# TAMIL NADU                          24872
# MAHARASHTRA                         21706
# MADHYA PRADESH                      18486
# JAMMU & KASHMIR                     17640
# ODISHA                              16582
# HARYANA                             12258
# PUNJAB                              10770
# KARNATAKA                           10630
# JHARKHAND                           10564
# CHHATTISGARH                         5260
# UTTARAKHAND                          4668
# KERALA                               3796

# %%
kid_top_20_state.plot.bar(color = 'orange')
# Out:
# <AxesSubplot:xlabel='STATE/UT'>
